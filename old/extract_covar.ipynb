# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('new_data/sample_dataset.csv')

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
cov_mat = df.cov()
cov_mat
# Out:
#                      hydrochlorothiazide  thyroxine  lisinopril  simvastatin  \
# hydrochlorothiazide             0.070859  -0.000760    0.019121     0.003750
# thyroxine                      -0.000760   0.064396   -0.001075     0.000166
# lisinopril                      0.019121  -0.001075    0.058896     0.005749
# simvastatin                     0.003750   0.000166    0.005749     0.049986
# ethinyl estradiol              -0.006958  -0.004340   -0.005780    -0.004938
# ...                                  ...        ...         ...          ...
# promazine                       0.000000   0.000000    0.000000     0.000000
# rofecoxib                       0.000000   0.000000    0.000000     0.000000
# streptokinase                   0.000000   0.000000    0.000000     0.000000
# troleandomycin                  0.000000   0.000000    0.000000     0.000000
# sulfamerazine                   0.000000   0.000000    0.000000     0.000000
#
# ...

# %%
cov_mat.describe()
# Out:
#        hydrochlorothiazide     thyroxine    lisinopril   simvastatin  \
# count         1.180000e+03  1.180000e+03  1.180000e+03  1.180000e+03
# mean          6.082813e-05  7.677469e-06  3.709898e-05  2.522073e-05
# std           2.205352e-03  1.887551e-03  1.836479e-03  1.496438e-03
# min          -6.958003e-03 -4.339743e-03 -5.779592e-03 -4.938184e-03
# 25%          -1.703148e-05 -1.270023e-05 -1.185432e-05 -8.673387e-06
# 50%          -8.515740e-07 -7.676108e-07 -6.973132e-07 -5.855264e-07
# 75%           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max           7.085862e-02  6.439564e-02  5.889647e-02  4.998639e-02
#
#        ethinyl estradiol  acetaminophen    amlodipine  atorvastatin  \
# count        1180.000000   1.180000e+03  1.180000e+03  1.180000e+03
# mean            0.000048   3.480561e-05  2.185150e-05  1.391279e-05
# std             0.002797   1.296522e-03  9.990934e-04  1.051486e-03
# min            -0.006958  -3.036147e-03 -3.164061e-03 -3.429500e-03
# ...

# %%
cov_mat = cov_mat.to_numpy()

# %%
np.save('new_data/parameters/cov_mat.npy', cov_mat)

# %%
mean = df.mean()

# %%
mean = mean.to_numpy()

# %%
np.save('new_data/parameters/means.npy', mean)

# %%
cols = df.columns.values

# %%
np.save('new_data/describe/column_names.npy', cols)
